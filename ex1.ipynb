# %% [markdown]
# <a href="https://colab.research.google.com/github/MaewTeam/basicPython_ImageProcessing/blob/master/ex1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-a3ccb346-929e-4745-bd64-e4e23f6287d9" name="files[]" multiple disabled />
#      <output id="result-a3ccb346-929e-4745-bd64-e4e23f6287d9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import os
# !ls
os.getcwd()
# Out:
# '8test1 (1).jpg'   8test1.jpg   sample_data
# '/content'

# %%
import cv2
items = os.listdir('/content')
print (items)
for each_image in items:
 if each_image.endswith(".jpg"):
   # print (each_image)
    full_path = "/content/" + each_image
    #print (full_path)
    #image = cv2.imread(full_path)
    #print (image)
# Out:
# ['.config', '8test1 (1).jpg', '8test1.jpg', 'sample_data']

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
im = mpimg.imread('/content/8test1.jpg')
plt.imshow(im)
from skimage.transform import resize

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread("/content/8test1.jpg")
img_cvt=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img_cvt)
plt.show()

# %%
from skimage.transform import resize
plt.imshow(im[120:140,220:240])

# %%
plt.imshow(img_cvt[120:140,220:240])

# %%
plt.imshow(resize(im,[16,16]))
#print(resize(im,[16,16]))
# Out:
# /usr/local/lib/python3.6/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
from skimage.transform import rotate
plt.imshow(rotate(im,45))

# %%
plt.imshow(rotate(im,180))

# %%
plt.subplot(131)
plt.title("Red")
plt.imshow(im[:,:,0])
plt.subplot(132)
plt.title("Green")
plt.imshow(im[:,:,1])
plt.subplot(133)
plt.title("Blue")
plt.imshow(im[:,:,2])
