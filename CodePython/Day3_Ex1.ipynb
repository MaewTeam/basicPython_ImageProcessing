# %% [markdown]
# ทำการ import packet ที่ต้องใช้งานทางด้านการ อ่าน-เขียนไฟล์ภาพ และ แสดงเป็นกราฟ

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %% [markdown]
# ทำการ import packet ที่ต้องใช้งานทางด้านการ ใช้ข้อมูลตัวอย่างรูป กับการประมวลผล

# %%
from skimage  import data,color 
from skimage.transform import resize

# %%
 # !cd
 im = data.moon()
 im = mpimg.imread('p1_rgb.jpg')
# Out:
# C:\Users\Teacher\Desktop\CodePython

# %%
print(im.shape)
print(im)
# Out:
# (225, 225, 3)
# [[[ 58 143 174]
#   [ 57 142 173]
#   [ 57 142 173]
#   ...
#   [ 80 156 169]
#   [ 80 156 169]
#   [ 82 158 171]]
#
#  [[ 55 146 175]
#   [ 55 146 175]
#   [ 54 145 174]
#   ...
#   [ 81 157 170]
#   [ 81 157 170]
#   [ 82 158 171]]
#
#  [[ 52 147 175]
#   [ 52 147 175]
#   [ 51 146 174]
#   ...
#   [ 80 159 174]
#   [ 80 159 174]
#   [ 81 160 175]]
#
#  ...
#
#  [[  0  37  94]
#   [  0  37  94]
#   [  0  37  94]
#   ...
#   [  0  37  94]
#   [  0  37  94]
#   [  0  36  93]]
#
#  [[  0  37  94]
#   [  0  37  94]
#   [  0  37  94]
#   ...
#   [  0  37  94]
#   [  0  37  94]
#   [  0  36  93]]
#
#  [[  0  37  94]
#   [  0  37  94]
#   [  0  37  94]
#   ...
#   [  0  35  93]
#   [  0  35  93]
#   [  1  36  94]]]

# %% [markdown]
# ขั้นตอนนี้เป็นการตัดภาพ( crop )เฉพาะ ตำแหน่งที่ต้องการ

# %%
plt.gray()
plt.imshow(im[1:100,1:100,0])

# %%
plt.gray()
plt.subplot(1,4,1)
plt.imshow(im)
plt.subplot(1,4,2)
plt.imshow(resize(im,[16,16]))
plt.subplot(1,4,3)
plt.imshow(resize(im,[32,32]))
plt.subplot(1,4,4)
plt.imshow(resize(im,[256,256]))

# %%
plt.imshow(resize(im[100:150,50:100],[1024,1024]))
